# %%
'''first, let's import libraries '''

import numpy as np
import matplotlib.pyplot as plt
import io
import pandas as pd

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#path = '/content/drive/My Drive/EuropHeight_samples/Babol_Height_R1.csv'
path = '/content/drive/My Drive/UrbanHeight/0_Tehran_Samples_03.csv'
Table0 = pd.read_csv(path)
#print(Table0)
#print(Table0.head())
#Table0.info()
Table0 = Table0[['3D1000_2_max','3D1000_2_mean','3D1000_2_stdDev','3D2000_2_max','3D2000_2_mean','3D2000_2_stdDev','3D3000_2_max','3D3000_2_mean','3D3000_2_stdDev',\
'3D4000_2_max','3D4000_2_mean','3D4000_2_stdDev','3D5000_2_max','3D5000_2_mean','3D5000_2_stdDev','3D6000_2_max','3D6000_2_mean','3D6000_2_stdDev',\
'3D7000_2_max','3D7000_2_mean','3D7000_2_stdDev','3D_2','Aqua_Day_2','Aqua_Night_2','CO2_2','CO_2','NO2_2','SO2_2','Terra_Day_2','Terra_Night_2']].dropna()
#Table0.value_counts()   # Categorical data

# %%
#path = '/content/drive/My Drive/EuropHeight_samples/Babol_Height_R1.csv'
path = '/content/drive/My Drive/UrbanHeight/0_Tehran_Samples_03.csv'
Table0 = pd.read_csv(path)
#print(Table0)
#print(Table0.head())
#Table0.info()
Table0 = Table0[['3D1000_1_max','3D1000_1_mean','3D1000_1_stdDev','3D2000_1_max','3D2000_1_mean','3D2000_1_stdDev','3D3000_1_max','3D3000_1_mean','3D3000_1_stdDev',\
'3D4000_1_max','3D4000_1_mean','3D4000_1_stdDev','3D5000_1_max','3D5000_1_mean','3D5000_1_stdDev','3D6000_1_max','3D6000_1_mean','3D6000_1_stdDev',\
'3D7000_1_max','3D7000_1_mean','3D7000_1_stdDev','3D_1','Aqua_Day_1','Aqua_Night_1','CO2_1','CO_1','NO2_1','SO2_1','Terra_Day_1','Terra_Night_1']].dropna()
#Table0.value_counts()   # Categorical data

# %%
#path = '/content/drive/My Drive/EuropHeight_samples/Babol_Height_R1.csv'
path = '/content/drive/My Drive/UrbanHeight/0_Tehran_Samples_03.csv'
Table0 = pd.read_csv(path)
#print(Table0)
#print(Table0.head())
#Table0.info()
Table0 = Table0[['3D1000_1_max','3D1000_1_mean','3D1000_1_stdDev','3D2000_1_max','3D2000_1_mean','3D2000_1_stdDev','3D3000_1_max','3D3000_1_mean','3D3000_1_stdDev',\
'3D4000_1_max','3D4000_1_mean','3D4000_1_stdDev','3D5000_1_max','3D5000_1_mean','3D5000_1_stdDev','3D6000_1_max','3D6000_1_mean','3D6000_1_stdDev',\
'3D7000_1_max','3D7000_1_mean','3D7000_1_stdDev','3D_1','Aqua_Day_1','Aqua_Night_1','CO2_1','CO_1','NO2_1','SO2_1','Terra_Day_1','Terra_Night_1',\
'3D1000_2_max','3D1000_2_mean','3D1000_2_stdDev','3D2000_2_max','3D2000_2_mean','3D2000_2_stdDev','3D3000_2_max','3D3000_2_mean','3D3000_2_stdDev',\
'3D4000_2_max','3D4000_2_mean','3D4000_2_stdDev','3D5000_2_max','3D5000_2_mean','3D5000_2_stdDev','3D6000_2_max','3D6000_2_mean','3D6000_2_stdDev',\
'3D7000_2_max','3D7000_2_mean','3D7000_2_stdDev','3D_2','Aqua_Day_2','Aqua_Night_2','CO2_2','CO_2','NO2_2','SO2_2','Terra_Day_2','Terra_Night_2']].dropna()
#Table0.value_counts()   # Categorical data

# %%
#AllData = pd.concat([Table0, Table1, Table2, Table3, Table4, Table5])
AllData = Table0
AllData.value_counts()
# Out:
# 3D1000_1_max  3D1000_1_mean  3D1000_1_stdDev  3D2000_1_max  3D2000_1_mean  3D2000_1_stdDev  3D3000_1_max  3D3000_1_mean  3D3000_1_stdDev  3D4000_1_max  3D4000_1_mean  3D4000_1_stdDev  3D5000_1_max  3D5000_1_mean  3D5000_1_stdDev  3D6000_1_max  3D6000_1_mean  3D6000_1_stdDev  3D7000_1_max  3D7000_1_mean  3D7000_1_stdDev  3D_1       Aqua_Day_1  Aqua_Night_1  CO2_1     CO_1      NO2_1     SO2_1     Terra_Day_1  Terra_Night_1  3D1000_2_max  3D1000_2_mean  3D1000_2_stdDev  3D2000_2_max  3D2000_2_mean  3D2000_2_stdDev  3D3000_2_max  3D3000_2_mean  3D3000_2_stdDev  3D4000_2_max  3D4000_2_mean  3D4000_2_stdDev  3D5000_2_max  3D5000_2_mean  3D5000_2_stdDev  3D6000_2_max  3D6000_2_mean  3D6000_2_stdDev  3D7000_2_max  3D7000_2_mean  3D7000_2_stdDev  3D_2       Aqua_Day_2  Aqua_Night_2  CO2_2     CO_2      NO2_2     SO2_2     Terra_Day_2  Terra_Night_2
# ...

# %%
import matplotlib.pyplot as plt
AllData.hist(bins=100, figsize=(20,15))
plt.show()

# %% [markdown]
# # Split Dataset into train and test sections

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(AllData, test_size=0.2, random_state=42)
print(len(train_set))
print(len(test_set))
# Out:
# 756
# 189

# %%
#X_train = train_set[['U1', 'U2', 'U3', 'U4', 'VH_A', 'VH_D1', 'VH_D2', 'VV_A', 'VV_D1', 'VV_D2', 'NL']]
X_train = train_set[['3D1000_2_max','3D1000_2_mean','3D1000_2_stdDev','3D2000_2_max','3D2000_2_mean','3D2000_2_stdDev','3D3000_2_max','3D3000_2_mean','3D3000_2_stdDev',\
'3D4000_2_max','3D4000_2_mean','3D4000_2_stdDev','3D5000_2_max','3D5000_2_mean','3D5000_2_stdDev','3D6000_2_max','3D6000_2_mean','3D6000_2_stdDev',\
'3D7000_2_max','3D7000_2_mean','3D7000_2_stdDev','3D_2']]
Y_train = train_set[['SO2_2']]
print(X_train.shape)
print(Y_train.shape)
# Out:
# (756, 22)
# (756, 1)

# %%
#X_train = train_set[['U1', 'U2', 'U3', 'U4', 'VH_A', 'VH_D1', 'VH_D2', 'VV_A', 'VV_D1', 'VV_D2', 'NL']]
X_train = train_set[['3D1000_1_max','3D1000_1_mean','3D1000_1_stdDev','3D2000_1_max','3D2000_1_mean','3D2000_1_stdDev','3D3000_1_max','3D3000_1_mean','3D3000_1_stdDev',\
'3D4000_1_max','3D4000_1_mean','3D4000_1_stdDev','3D5000_1_max','3D5000_1_mean','3D5000_1_stdDev','3D6000_1_max','3D6000_1_mean','3D6000_1_stdDev',\
'3D7000_1_max','3D7000_1_mean','3D7000_1_stdDev','3D_1']]
Y_train = train_set[['Aqua_Night_1']]
print(X_train.shape)
print(Y_train.shape)
# Out:
# (756, 22)
# (756, 1)

# %%
#X_train = train_set[['U1', 'U2', 'U3', 'U4', 'VH_A', 'VH_D1', 'VH_D2', 'VV_A', 'VV_D1', 'VV_D2', 'NL']]
X_train = train_set[['3D1000_1_max','3D1000_1_mean','3D1000_1_stdDev','3D2000_1_max','3D2000_1_mean','3D2000_1_stdDev','3D3000_1_max','3D3000_1_mean','3D3000_1_stdDev',\
'3D4000_1_max','3D4000_1_mean','3D4000_1_stdDev','3D5000_1_max','3D5000_1_mean','3D5000_1_stdDev','3D6000_1_max','3D6000_1_mean','3D6000_1_stdDev',\
'3D7000_1_max','3D7000_1_mean','3D7000_1_stdDev','3D_1',\
'3D1000_2_max','3D1000_2_mean','3D1000_2_stdDev','3D2000_2_max','3D2000_2_mean','3D2000_2_stdDev','3D3000_2_max','3D3000_2_mean','3D3000_2_stdDev',\
'3D4000_2_max','3D4000_2_mean','3D4000_2_stdDev','3D5000_2_max','3D5000_2_mean','3D5000_2_stdDev','3D6000_2_max','3D6000_2_mean','3D6000_2_stdDev',\
'3D7000_2_max','3D7000_2_mean','3D7000_2_stdDev','3D_2','Terra_Night_1']]
Y_train = train_set[['Terra_Night_2']]
print(X_train.shape)
print(Y_train.shape)
# Out:
# (756, 45)
# (756, 1)

# %%
#X_test = test_set[['U1', 'U2', 'U3', 'U4', 'VH_A', 'VH_D1', 'VH_D2', 'VV_A', 'VV_D1', 'VV_D2', 'NL']]
X_test = test_set[['3D1000_2_max','3D1000_2_mean','3D1000_2_stdDev','3D2000_2_max','3D2000_2_mean','3D2000_2_stdDev','3D3000_2_max','3D3000_2_mean','3D3000_2_stdDev',\
'3D4000_2_max','3D4000_2_mean','3D4000_2_stdDev','3D5000_2_max','3D5000_2_mean','3D5000_2_stdDev','3D6000_2_max','3D6000_2_mean','3D6000_2_stdDev',\
'3D7000_2_max','3D7000_2_mean','3D7000_2_stdDev','3D_2']]
Y_test = test_set[['SO2_2']]
print(X_test.shape)
print(Y_test.shape)
# Out:
# (189, 22)
# (189, 1)

# %%
#X_test = test_set[['U1', 'U2', 'U3', 'U4', 'VH_A', 'VH_D1', 'VH_D2', 'VV_A', 'VV_D1', 'VV_D2', 'NL']]
X_test = test_set[['3D1000_1_max','3D1000_1_mean','3D1000_1_stdDev','3D2000_1_max','3D2000_1_mean','3D2000_1_stdDev','3D3000_1_max','3D3000_1_mean','3D3000_1_stdDev',\
'3D4000_1_max','3D4000_1_mean','3D4000_1_stdDev','3D5000_1_max','3D5000_1_mean','3D5000_1_stdDev','3D6000_1_max','3D6000_1_mean','3D6000_1_stdDev',\
'3D7000_1_max','3D7000_1_mean','3D7000_1_stdDev','3D_1',\
'3D1000_2_max','3D1000_2_mean','3D1000_2_stdDev','3D2000_2_max','3D2000_2_mean','3D2000_2_stdDev','3D3000_2_max','3D3000_2_mean','3D3000_2_stdDev',\
'3D4000_2_max','3D4000_2_mean','3D4000_2_stdDev','3D5000_2_max','3D5000_2_mean','3D5000_2_stdDev','3D6000_2_max','3D6000_2_mean','3D6000_2_stdDev',\
'3D7000_2_max','3D7000_2_mean','3D7000_2_stdDev','3D_2','Terra_Night_1']]
Y_test = test_set[['Terra_Night_2']]
print(X_test.shape)
print(Y_test.shape)
# Out:
# (189, 45)
# (189, 1)

# %% [markdown]
# Call Accracy assessment libraries

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %% [markdown]
# # Linear Regression with Ordinary Least Squares

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(X_train, Y_train) # y_train, not y_train_5
# Out:
# LinearRegression()

# %%
Y_predict = reg.predict(X_train)
LR_train_MSE = (mean_absolute_error(Y_train, Y_predict))
LR_train_R = (r2_score(Y_train, Y_predict))

# %%
print(reg.coef_)
# Out:
# [[ 2.51501471e-02 -8.00039819e-01  3.36569140e-02 -7.51780428e-03
#   -2.00952522e+00  7.06852645e-01 -1.89428072e-02 -4.17495442e+00
#    3.18201216e+00 -2.13774912e-02  3.62973139e+00 -1.72683118e+00
#    2.19771472e-02  6.41208781e+00 -2.45214390e+00 -9.48113182e-03
#    2.69462977e+00 -4.63469233e+00  1.14133462e-02  1.70191975e+01
#   -2.75468375e+00 -7.94997217e-03  4.49374229e-03  9.78569927e-01
#   -2.04811770e-01  2.67216330e-03  2.18382911e+00 -8.38555784e-01
#    4.05097275e-02  3.68646425e+00 -3.00280227e+00  7.11367831e-03
#   -2.57738627e+00  1.47391039e+00 -2.03056826e-02 -6.80443370e+00
#    2.71782053e+00 -8.87365297e-03 -2.41870473e+00  4.26578061e+00
#   -3.79376581e-03 -1.70454027e+01  3.21471195e+00 -6.90990477e-03
#    6.71496040e-01]]

# %%
print( LR_train_R)
print(LR_train_MSE)
# Out:
# 0.9284678342326073
# 0.6754566611111761

# %%
Y_predict = reg.predict(X_test)
LR_test_MSE = (mean_absolute_error(Y_test, Y_predict))
LR_test_R = (r2_score(Y_test, Y_predict))

# %%
print( LR_test_R)
print(LR_test_MSE)
# Out:
# 0.9333715204824601
# 0.679453530060813

# %% [markdown]
# # Ridge regression

# %%
from sklearn import linear_model
reg = linear_model.Ridge(alpha=.5)
reg.fit(X_train, Y_train) # y_train, not y_train_5
# Out:
# Ridge(alpha=0.5)

# %%
Y_predict = reg.predict(X_train)
RR_train_MSE = (mean_absolute_error(Y_train, Y_predict))
RR_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = reg.predict(X_test)
RR_test_MSE = (mean_absolute_error(Y_test, Y_predict))
RR_test_R = (r2_score(Y_test, Y_predict))

# %%
print( RR_train_R)
print( RR_test_R)
# Out:
# 0.6714523744633674
# 0.6777041023055268

# %% [markdown]
# # Bayesian Ridge Regression

# %%
from sklearn import linear_model
reg = linear_model.BayesianRidge()
reg.fit(X_train, Y_train) # y_train, not y_train_5
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False)

# %%
Y_predict = reg.predict(X_train)
BRR_train_MSE = (mean_absolute_error(Y_train, Y_predict))
BRR_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = reg.predict(X_test)
BRR_test_MSE = (mean_absolute_error(Y_test, Y_predict))
BRR_test_R = (r2_score(Y_test, Y_predict))

# %% [markdown]
# # Support Vector Regression- Linear

# %%
 from sklearn.svm import SVR
 reg = SVR(kernel='linear')
 reg.fit(X_train, Y_train)
 #from sklearn.model_selection import cross_val_score
# svr_rbf = SVR(kernel='rbf', C=300, gamma=0.1, epsilon=.1)
 #scores = cross_val_score(svr_rbf, AllData[['U1', 'U2', 'U3', 'U4', 'VH_A', 'VH_D1', 'VH_D2', 'VV_A', 'VV_D1', 'VV_D2', 'NL']], AllData[['Height']], cv=5)
 #scores
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %%
Y_predict = reg.predict(X_train)
SVRL_train_MSE = (mean_absolute_error(Y_train, Y_predict))
SVRL_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = reg.predict(X_test)
SVRL_test_MSE = (mean_absolute_error(Y_test, Y_predict))
SVRL_test_R = (r2_score(Y_test, Y_predict))

# %%
print(SVRL_train_R)
print(SVRL_test_R)
# Out:
# -0.0035334129323802976
# -0.005469514558650523

# %% [markdown]
# # Support Vector Regression- polynomial

# %%
 from sklearn.svm import SVR
 reg = SVR(kernel='poly', degree=2)
 reg.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=2, epsilon=0.1, gamma='scale',
#     kernel='poly', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
Y_predict = reg.predict(X_train)
SVRP_train_MSE = (mean_absolute_error(Y_train, Y_predict))
SVRP_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = reg.predict(X_test)
SVRP_test_MSE = (mean_absolute_error(Y_test, Y_predict))
SVRP_test_R = (r2_score(Y_test, Y_predict))

# %% [markdown]
# # Support Vector Regression- RBF

# %%
 from sklearn.svm import SVR
 reg = SVR(kernel='rbf')
 reg.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
Y_predict = reg.predict(X_train)
SVRR_train_MSE = (mean_absolute_error(Y_train, Y_predict))
SVRR_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = reg.predict(X_test)
SVRR_test_MSE = (mean_absolute_error(Y_test, Y_predict))
SVRR_test_R = (r2_score(Y_test, Y_predict))

# %% [markdown]
# # Stochastic Gradient Descent huber

# %%
 from sklearn import linear_model
reg = linear_model.SGDRegressor(loss='huber')  # ‘huber’, ‘epsilon_insensitive
reg.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='invscaling', loss='huber', max_iter=1000,
#              n_iter_no_change=5, penalty='l2', power_t=0.25, random_state=None,
#              shuffle=True, tol=0.001, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
Y_predict = reg.predict(X_train)
SGDH_train_MSE = (mean_absolute_error(Y_train, Y_predict))
SGDH_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = reg.predict(X_test)
SGDH_test_MSE = (mean_absolute_error(Y_test, Y_predict))
SGDH_test_R = (r2_score(Y_test, Y_predict))

# %% [markdown]
# # Stochastic Gradient Descent epsilon_insensitive

# %%
 from sklearn import linear_model
reg = linear_model.SGDRegressor(loss='epsilon_insensitive')  # ‘huber’, ‘epsilon_insensitive
reg.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='invscaling', loss='epsilon_insensitive',
#              max_iter=1000, n_iter_no_change=5, penalty='l2', power_t=0.25,
#              random_state=None, shuffle=True, tol=0.001,
#              validation_fraction=0.1, verbose=0, warm_start=False)

# %%
Y_predict = reg.predict(X_train)
SGDE_train_MSE = (mean_absolute_error(Y_train, Y_predict))
SGDE_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = reg.predict(X_test)
SGDE_test_MSE = (mean_absolute_error(Y_test, Y_predict))
SGDE_test_R = (r2_score(Y_test, Y_predict))

# %% [markdown]
# # Decision Trees

# %%
from sklearn import tree
reg = tree.DecisionTreeRegressor(max_depth=5)
reg.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=5,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
Y_predict = reg.predict(X_train)
DT_train_MSE = (mean_absolute_error(Y_train, Y_predict))
DT_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = reg.predict(X_test)
DT_test_MSE = (mean_absolute_error(Y_test, Y_predict))
DT_test_R = (r2_score(Y_test, Y_predict))

# %% [markdown]
# # Neural network

# %%
from sklearn import neural_network
reg = neural_network.MLPRegressor()
reg.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1599: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# MLPRegressor()

# %%
Y_predict = reg.predict(X_train)
NN_train_MSE = (mean_absolute_error(Y_train, Y_predict))
NN_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = reg.predict(X_test)
NN_test_MSE = (mean_absolute_error(Y_test, Y_predict))
NN_test_R = (r2_score(Y_test, Y_predict))

# %%
print(NN_train_R)
print(NN_test_R)
# Out:
# -646.721712241889
# -675.9265716405068

# %% [markdown]
# # Gradient Boosting Regressor

# %%
from sklearn import ensemble 
reg = ensemble.GradientBoostingRegressor()
reg.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_gb.py:494: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor()

# %%
Y_predict = reg.predict(X_train)
GB_train_MSE = (mean_absolute_error(Y_train, Y_predict))
GB_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = reg.predict(X_test)
GB_test_MSE = (mean_absolute_error(Y_test, Y_predict))
GB_test_R = (r2_score(Y_test, Y_predict))

# %%
print(GB_train_R)
print(GB_test_R)
# Out:
# 0.9817736293761801
# 0.9618737335825449

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn import ensemble 
reg = ensemble.RandomForestRegressor(max_depth=5)
reg.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor(max_depth=5)

# %%
Y_predict = reg.predict(X_train)
RF_train_MSE = (mean_absolute_error(Y_train, Y_predict))
RF_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = reg.predict(X_test)
RF_test_MSE = (mean_absolute_error(Y_test, Y_predict))
RF_test_R = (r2_score(Y_test, Y_predict))

# %%
print(RF_train_R)
print(RF_test_R)
# Out:
# 0.9617290662178771
# 0.9458355101342166

# %%
plt.barh(X_train.columns , reg.feature_importances_)
# Out:
# <BarContainer object of 22 artists>

# %%
print(reg.feature_importances_)
# Out:
# [0.00580162 0.00770423 0.00774155 0.02091574 0.00485129 0.0198409
#  0.03395196 0.00432301 0.00928009 0.00841147 0.00505706 0.00767808
#  0.26882106 0.00382194 0.0102798  0.21277778 0.00923589 0.01873741
#  0.29559062 0.007705   0.03355288 0.00392062]

# %% [markdown]
# # Voting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import VotingRegressor

# Training classifiers
reg1 = GradientBoostingRegressor(random_state=1)
reg2 = RandomForestRegressor(max_depth=5, random_state=1)
reg3 = LinearRegression()
ereg = VotingRegressor(estimators=[('gb', reg1), ('rf', reg2), ('lr', reg3)])
ereg = ereg.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_voting.py:406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
Y_predict = ereg.predict(X_train)
VOT_train_MSE = (mean_absolute_error(Y_train, Y_predict))
VOT_train_R = (r2_score(Y_train, Y_predict))

# %%
Y_predict = ereg.predict(X_test)
VOT_test_MSE = (mean_absolute_error(Y_test, Y_predict))
VOT_test_R = (r2_score(Y_test, Y_predict))

# %%
print('VOT_train_R=', VOT_train_R)
print('VOT_train_MSE=', VOT_train_MSE)
print('VOT_test_R=', VOT_test_R)
print('VOT_test_MSE=', VOT_test_MSE)
# Out:
# VOT_train_R= 0.2977937391841806
# VOT_train_MSE= 4.1469533213463645
# VOT_test_R= 0.23834096194566134
# VOT_test_MSE= 4.249880382063844

# %%
print( LR_train_R)
print(LR_train_MSE)
print(RR_train_R)
print(RR_train_MSE)
print(BRR_train_R)
print(BRR_train_MSE)
print(SVRL_train_R)
print(SVRL_train_MSE)
print(SVRP_train_R)
print(SVRP_train_MSE)
print(SVRR_train_R)
print(SVRR_train_MSE)
print(SGDH_train_R)
print(SGDH_train_MSE)
print(SGDE_train_R)
print(SGDE_train_MSE)
print(DT_train_R)
print(DT_train_MSE)
print(NN_train_R)
print(NN_train_MSE)
print(GB_train_R)
print(GB_train_MSE)
print(RF_train_R)
print(RF_train_MSE)
print(VOT_train_R)
print(VOT_train_MSE)
# Out:
# 0.22087571256550764
# 4.403799231414721
# 0.22087523007798515
# 4.403672208817826
# 0.22079531981134803
# 4.402174051500676
# 0.12416777399810408
# 4.108837666735582
# 0.07873025519815002
# 4.16825986665556
# 0.18890040314151346
# 3.8561671268271276
# -0.07058672302597291
# 4.455673567593585
# 0.10521163639331632
# 4.128643125605832
# 0.26335516701690254
# 4.190881076495184
# 0.2715842712471964
# 4.046877069351582
# 0.3375482381424315
# 4.036292122420434
# 0.2914819292170887
# 4.1273369748556235
# 0.2977937391841806
# 4.1469533213463645

# %%
print(LR_test_R)
print(LR_test_MSE)
print(RR_test_R)
print(RR_test_MSE)
print(BRR_test_R)
print(BRR_test_MSE)
print(SVRL_test_R)
print(SVRL_test_MSE)
print(SVRP_test_R)
print(SVRP_test_MSE)
print(SVRR_test_R)
print(SVRR_test_MSE)
print(SGDH_test_R)
print(SGDH_test_MSE)
print(SGDE_test_R)
print(SGDE_test_MSE)
print(DT_test_R)
print(DT_test_MSE)
print(NN_test_R)
print(NN_test_MSE)
print(GB_test_R)
print(GB_test_MSE)
print(RF_test_R)
print(RF_test_MSE)
print(VOT_test_R)
print(VOT_test_MSE)
# Out:
# 0.2228360860403491
# 4.449504450591523
# 0.22280051925946476
# 4.449510794329943
# 0.22240579017087714
# 4.4490914458372846
# 0.12094245450494856
# 4.19014319177008
# 0.07380649761717795
# 4.252986086970695
# 0.18066846551150761
# 3.913851741852538
# -0.07636376855677485
# 4.542400367845816
# 0.10109242799345808
# 4.2115554270417634
# 0.18318950720981975
# 4.334840929649432
# 0.2403859343668292
# 4.145723484835857
# 0.23520224995951633
# 4.197436436157602
# 0.226844845146827
# 4.24076599092137
# 0.23834096194566134
# 4.249880382063844

# %%
"""
print('LR_train_R=', LR_train_R)
print('LR_train_MSE=', LR_train_MSE)
print('RR_train_R=', RR_train_R)
print('RR_train_MSE=', RR_train_MSE)
print('BRR_train_R=', BRR_train_R)
print('BRR_train_MSE=', BRR_train_MSE)
print('SVRL_train_R=', SVRL_train_R)
print('SVRL_train_MSE=', SVRL_train_MSE)
print('SVRP_train_R=', SVRP_train_R)
print('SVRP_train_MSE=', SVRP_train_MSE)
print('SVRR_train_R=', SVRR_train_R)
print('SVRR_train_MSE=', SVRR_train_MSE)
print('SGDH_train_R=', SGDH_train_R)
print('SGDH_train_MSE=', SGDH_train_MSE)
print('SGDE_train_R=', SGDE_train_R)
print('SGDE_train_MSE=', SGDE_train_MSE)
print('DT_train_R=', DT_train_R)
print('DT_train_MSE=', DT_train_MSE)
print('NN_train_R=', NN_train_R)
print('NN_train_MSE=', NN_train_MSE)
print('GB_train_R=', GB_train_R)
print('GB_train_MSE=', GB_train_MSE)
print('RF_train_R=', RF_train_R)
print('RF_train_MSE=', RF_train_MSE)
print('VOT_train_R=', VOT_train_R)
print('VOT_train_MSE=', VOT_train_MSE)

print('LR_test_R=', LR_test_R)
print('LR_test_MSE=', LR_test_MSE)
print('RR_test_R=', RR_test_R)
print('RR_test_MSE=', RR_test_MSE)
print('BRR_test_R=', BRR_test_R)
print('BRR_test_MSE=', BRR_test_MSE)
print('SVRL_test_R=', SVRL_test_R)
print('SVRL_test_MSE=', SVRL_test_MSE)
print('SVRP_test_R=', SVRP_test_R)
print('SVRP_test_MSE=', SVRP_test_MSE)
print('SVRR_test_R=', SVRR_test_R)
print('SVRR_test_MSE=', SVRR_test_MSE)
print('SGDH_test_R=', SGDH_test_R)
print('SGDH_test_MSE=', SGDH_test_MSE)
print('SGDE_test_R=', SGDE_test_R)
print('SGDE_test_MSE=', SGDE_test_MSE)
print('DT_test_R=', DT_test_R)
print('DT_test_MSE=', DT_test_MSE)
print('NN_test_R=', NN_test_R)
print('NN_test_MSE=', NN_test_MSE)
print('GB_test_R=', GB_test_R)
print('GB_test_MSE=', GB_test_MSE)
print('RF_test_R=', RF_test_R)
print('RF_test_MSE=', RF_test_MSE)
print('VOT_test_R=', VOT_test_R)
print('VOT_test_MSE=', VOT_test_MSE)
"""
# Out:
# "\nprint('LR_train_R=', LR_train_R)\nprint('LR_train_MSE=', LR_train_MSE)\nprint('RR_train_R=', RR_train_R)\nprint('RR_train_MSE=', RR_train_MSE)\nprint('BRR_train_R=', BRR_train_R)\nprint('BRR_train_MSE=', BRR_train_MSE)\nprint('SVRL_train_R=', SVRL_train_R)\nprint('SVRL_train_MSE=', SVRL_train_MSE)\nprint('SVRP_train_R=', SVRP_train_R)\nprint('SVRP_train_MSE=', SVRP_train_MSE)\nprint('SVRR_train_R=', SVRR_train_R)\nprint('SVRR_train_MSE=', SVRR_train_MSE)\nprint('SGDH_train_R=', SGDH_train_R)\nprint('SGDH_train_MSE=', SGDH_train_MSE)\nprint('SGDE_train_R=', SGDE_train_R)\nprint('SGDE_train_MSE=', SGDE_train_MSE)\nprint('DT_train_R=', DT_train_R)\nprint('DT_train_MSE=', DT_train_MSE)\nprint('NN_train_R=', NN_train_R)\nprint('NN_train_MSE=', NN_train_MSE)\nprint('GB_train_R=', GB_train_R)\nprint('GB_train_MSE=', GB_train_MSE)\nprint('RF_train_R=', RF_train_R)\nprint('RF_train_MSE=', RF_train_MSE)\nprint('VOT_train_R=', VOT_train_R)\nprint('VOT_train_MSE=', VOT_train_MSE)\n\nprint('LR
# ...
